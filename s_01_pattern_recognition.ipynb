# %% [markdown]
# # Signal Template Matching
#
# ## 1-D case

# %%
import matplotlib.pyplot as plt
import math

# Input signal
input_signal = [0, 123, 23, 21, 50, 61, 52, 43, 67, 21, 52, 89, 12, 2, 53, 63, 55, 23, 54, 21]

plt.plot(input_signal)
plt.ylabel('Signal Intensity')
plt.show()

# %%
pattern_to_find = [50, 60, 50]
plt.plot(pattern_to_find)
plt.ylabel('Query signal')
plt.show()

# %% [markdown]
# ## How to detect signal?
#
# Note, there are two entries of signal at position 4 and 14
#
# ### 1. Bruteforce approach

# %%
def window_centered(source_signal, start_position, window_size):
    signal_window=source_signal[start_position:start_position+window_size]
    summ = 0.0
    for v in signal_window:
        summ = summ + v
    average = summ / window_size
    for i in range(window_size):
        signal_window[i] = signal_window[i] - average
    return signal_window

def signal_norm(input_signal):
    square_summ = 0.0
    for v in input_signal:
        square_summ = square_summ + v**2
    return math.sqrt(square_summ)

def normalized_cross_correlation(input_signal, pattern_signal):
    pattern_len = len(pattern_signal)
    pattern_signal_centered = window_centered(pattern_signal, 0, pattern_len) 
    for i in range(len(input_signal) - pattern_signal):
        pass

normalized_cross_correlation(input_signal, pattern_to_find)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-b50239a08c76> in <module>
#      15         pass
#      16
# ---> 17 normalized_cross_correlation(input_signal, pattern_to_find)
#
# <ipython-input-28-b50239a08c76> in normalized_cross_correlation(input_signal, pattern_signal)
#      12     pattern_len = len(pattern_signal)
#      13     pattern_signal_centered = window_centered(pattern_signal, 0, pattern_len)
# ---> 14     for i in range(len(input_signal) - pattern_signal):
#      15         pass
#      16
#
# <ipython-input-28-b50239a08c76> in normalized_cross_correlation(input_signal, pattern_signal)
#      12     pattern_len = len(pattern_signal)
#      13     pattern_signal_centered = window_centered(pattern_signal, 0, pattern_len)
# ---> 14     for i in range(len(input_signal) - pattern_signal):
#      15         pass
#      16
#
# ...
